# %%
import os
from dotenv import load_dotenv

# %%
from langchain_community.llms import Ollama
import streamlit as st
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
load_dotenv()
# Out:
# True

# %%
prompt=ChatPromptTemplate.from_messages(
    [
        ("system","Please respond to the question asked"),
        ("user","Question:{question}")
    ]
)

# %%
prompt
# Out:
# ChatPromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Please respond to the question asked'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, template='Question:{question}'), additional_kwargs={})])

# %%
st.title("Langchain Demo with LLAMA2")
input_text=st.text_input("What question you have in mind?")
# Out:
# 2026-08-26 15:36:49.155 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-26 15:36:49.301
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\MyCode\Gen-AI\LangChain\.venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-08-26 15:36:49.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-26 15:36:49.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-26 15:36:49.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-26 15:36:49.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-26 15:36:49.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-26 15:36:49.305 Session state does not function when running a script without `streamlit run`
# 2026-08-26 15:36:49.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-26 15:36:49.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-26 15:36:49.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
from langchain_ollama import OllamaLLM
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# Prompt
prompt = ChatPromptTemplate.from_messages([
    ("system", "Please respond to the question asked"),
    ("user", "Question: {question}")
])

# Correct LLM initialization
llm = OllamaLLM(model="gemma:2b")

# Output parser
output_parser = StrOutputParser()

# Build chain
chain = prompt | llm | output_parser

# Run
response = chain.invoke({"question": "Explain RAG simply"})
print(response)
# Out:
# Sure. Here's a simple explanation of RAG:
#
# **R**esources are the foundation of any successful project. They can be people, time, money, or other resources needed to complete a task.
#
# **A**ttentions are the activities and tasks required to achieve the project's goals.
#
# **G**oals are the desired outcomes of the project, which are what the project is ultimately working towards.
#
# In essence, RAG helps us understand the crucial elements that need to be in place for a project to be successful. It's like a roadmap that guides us through the project's stages and ensures we don't forget any essential step.
