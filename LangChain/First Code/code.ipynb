# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")
## Langsmith Tracking
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_community.llms import Ollama
# Out:
# C:\Users\Adit Sharma\AppData\Local\Temp\ipykernel_25956\3930454691.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.llms import Ollama

# %%
llm = Ollama(model="llama3")

response = llm.invoke("Explain RAG and GenAI simply")
print(response)
# Out:
# C:\Users\Adit Sharma\AppData\Local\Temp\ipykernel_25956\128072421.py:1: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaLLM``.
#   llm = Ollama(model="llama3")
# Failed to multipart ingest runs: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# **RAG:**
#
# RAG stands for "Recurrent And Generative". It's a type of neural network architecture designed for generating text that is coherent and natural-sounding. Here's a simplified overview:
#
# * **Recurrent**: The network uses Recurrent Neural Networks (RNNs) to process input sequences (e.g., sentences) one element at a time, maintaining a hidden state that captures the context.
# * **Generative**: The network is trained to generate new text based on a given prompt or input sequence. It predicts the next word in a sequence, given the previous words, to create a coherent and natural-sounding text.
#
# RAG models are particularly useful for applications like language translation, chatbots, and text summarization.
#
# **GenAI:**
#
# GenAI (short for "Generalized Artificial Intelligence") is a framework for developing AI models that can learn from diverse data sources and adapt to new situations. Here's a simplified overview:
#
# * **Generalized**: GenAI is designed to be a general-purpose AI framework that can be applied to various domains, such as text, images, or audio.
# * **Artificial Intelligence**: The framework is centered around developing AI models that can learn from data, make decisions, and adapt to new situations.
#
# GenAI's key features include:
#
# * Multi-modal data processing: GenAI can handle various data formats, such as text, images, and audio.
# * Transfer learning: GenAI allows models to learn from one domain and adapt to another, reducing the need for retraining from scratch.
# * Explainability: GenAI provides tools for understanding and interpreting AI model decisions, which is essential for building trust in AI systems.
#
# GenAI's applications include areas like natural language processing, computer vision, and decision-making systems.
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are an expert AI Engineer running on a local Ollama model. Respond with clear, technical, and accurate explanations."),
        ("user", "{input}")
    ]
)

# %%
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer running on a local Ollama model. Respond with clear, technical, and accurate explanations.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain=prompt|llm

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# Langsmith! It's an intriguing topic. Langsmith is a fascinating open-source framework for natural language processing (NLP) and machine learning (ML) that enables developers to build custom language models. It's specifically designed for building large-scale, production-ready language models.
#
# Langsmith is built on top of the popular TensorFlow and Keras libraries, which provides a seamless integration with the TensorFlow ecosystem. It's particularly well-suited for building transformer-based models, such as BERT, RoBERTa, and XLNet.
#
# One of the key features of Langsmith is its ability to support multi-device training, which allows developers to train models on multiple devices simultaneously. This feature is particularly useful for large-scale language model training, as it enables parallel processing and can significantly reduce training times.
#
# Langsmith also provides a range of pre-built components and utilities for common NLP tasks, such as text preprocessing, tokenization, and sentence encoding. These components are designed to be modular and easy to use, making it simple to integrate them into your own projects.
#
# Another notable feature of Langsmith is its support for automatic differentiation, which enables efficient computation of gradients during training. This feature is particularly useful for building complex neural networks with many parameters.
#
# Langsmith is an excellent choice for developers looking to build custom language models for a wide range of applications, from chatbots and virtual assistants to text classification and sentiment analysis. Its flexibility, scalability, and ease of use make it an attractive option for both beginners and experienced developers.
#
# In summary, Langsmith is a powerful open-source framework for NLP and ML that enables developers to build custom language models. Its support for multi-device training, pre-built components, and automatic differentiation make it an excellent choice for building large-scale language models.
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %%
type(response)
# Out:
# str

# %%
## stroutput Parser

from langchain_core.output_parsers import StrOutputParser
output_parser=StrOutputParser()
chain=prompt|llm|output_parser

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# Langsmith! It's a fascinating topic in the realm of Natural Language Processing (NLP). Langsmith is an open-source, cloud-based language model developed by Meta AI. It's a transformer-based architecture that can generate human-like text, perform language translation, and even engage in dialogue.
#
# Langsmith's key features include:
#
# 1. **Multimodal support**: Langsmith can process and generate text, as well as understand and respond to image and video inputs.
# 2. **Conditional generation**: It can generate text conditioned on a specific prompt, topic, or style, making it useful for applications like text summarization, chatbots, and content generation.
# 3. **Conversational dialogue**: Langsmith can engage in natural-sounding conversations, leveraging its ability to understand context and respond accordingly.
# 4. **Language translation**: It supports translation between multiple languages, including popular languages like English, Spanish, French, and many others.
# 5. **Customizability**: Langsmith allows for fine-tuning and customization through its open-source framework, making it a popular choice for developers and researchers.
#
# Langsmith is built on top of the popular Hugging Face Transformers library, which provides a unified interface for various transformer models, including BERT, RoBERTa, and more. This allows developers to easily integrate Langsmith with other NLP models and frameworks.
#
# In terms of technical specifications, Langsmith is based on a transformer architecture with a 12-layer encoder and 6-layer decoder, using the Attention mechanism. It's trained on a massive dataset of text from the internet, books, and other sources, which enables it to learn patterns and relationships in language.
#
# Langsmith has many potential applications, including:
#
# * Conversational AI assistants
# * Language translation tools
# * Content generation platforms
# * Chatbots and messaging systems
# * Text summarization and analysis tools
#
# Overall, Langsmith is an impressive language model that can process and generate human-like text, making it a valuable tool for NLP research and development.
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
